# %%
import pandas as pd

# %%
file_path = ("/Users/agnekrupinskaite/PycharmProjects/agkrupi-DWWP.4.1/Data_preprocessing_full_files/washington_post_v4_full.csv")

df = pd.read_csv(file_path, header=0, index_col=0, low_memory=False)

# %%
df.race_source.unique()
# Out:
# array(['not_available', nan, 'photo', 'clip', 'public_record', 'other',
#        'undetermined'], dtype=object)

# %%
df.columns
# Out:
# Index(['date', 'threat_type', 'flee_status', 'armed_with', 'city', 'county',
#        'state', 'latitude', 'longitude', 'location_precision', 'name', 'age',
#        'gender', 'race', 'race_source', 'was_mental_illness_related',
#        'body_camera', 'agency_ids', 'Retrieved_name', 'name_similarity',
#        'name_source', 'first_name', 'second_name', 'third_name', 'fourth_name',
#        'fifth_name', 'Retrieved_gender_v1', 'Retrieved_gender_v2',
#        'Retrieved_gender_guesser', 'gender_source', 'Retrieved_age_v1',
#        'Retrieved_age_v2', 'age_source', 'Retrieved_flee_status_v1',
#        'Retrieved_flee_status_v2', 'flee_status_source',
#        'Retrieved_armed_with_v1', 'Retrieved_armed_with_v2',
#        'armed_with_source', 'armed_with_v1', 'Retrieved_threat_type_v1',
#        'Retrieved_threat_type_v2', 'Retrieved_race_v1', 'Retrieved_race_v2',
#        'pctwhite_x_x', 'pctblack_x_x', 'pctapi_x_x', 'pctaian_x_x',
# ...

# %%
for column in df.columns:
    print(df[column].unique())
# Out:
# ['2015-01-02' '2015-01-03' '2015-01-04' ... '2024-02-12' '2024-02-13'
#  '2024-02-14']
# ['point' 'move' 'attack' 'shoot' 'accident' 'threat' 'undetermined' 'flee'
#  'armed']
# ['not' 'car' 'foot' 'other' 'undetermined']
# ['gun' 'unarmed' 'replica' 'other_or_multiple' 'edged_weapon'
#  'undetermined' 'blunt_object' 'vehicle']
# ['Shelton' 'Aloha' 'Wichita' ... 'Glenn Heights' 'Arverne' 'Manassas']
# ['Mason' 'Washington' 'Sedgwick' ... 'Dale' 'Young' 'Sheridan']
# ['WA' 'OR' 'KS' 'CA' 'CO' 'OK' 'AZ' 'IA' 'PA' 'TX' 'OH' 'LA' 'MT' 'UT'
#  'AR' 'IL' 'NV' 'NM' 'MN' 'MO' 'VA' 'NJ' 'IN' 'KY' 'MA' 'NH' 'FL' 'ID'
#  'MD' 'NE' 'MI' 'GA' 'TN' 'NC' 'AK' 'NY' 'ME' 'AL' 'MS' 'WI' 'SC' 'DE'
#  'DC' 'WV' 'HI' 'WY' 'ND' 'CT' 'SD' 'VT' 'RI']
# [47.246826   45.4874214  37.694766   ... 40.92902527 38.80496078
#  44.8078611 ]
# [-123.121592   -122.8916961   -97.280554   ...  -89.49143132  -77.51618916
#  -106.94841972]
# ['not_available' 'block' 'city_based' 'intersection' 'address'
# ...

# %% [markdown]
# ['gun' 'unarmed' 'replica' 'other_or_multiple' 'edged_weapon'
#  'undetermined' 'blunt_object' 'vehicle']
#
# ['A' 'W' 'H' 'B' 'O' 'undetermined' 'N' 'W;B;N' 'N;H' 'W;H' 'B;H' 'W;B']
# ['not_available' nan 'photo' 'clip' 'public_record' 'other' 'undetermined']
#
#
#
# ['Washington_Post' 'undetermined' 'Fatal_Encounters']
#
# ['Washington_Post' 'mode' 'Fatal_Encounters']
# [nan 'Not fleeing' 'Fleeing/Vehicle' 'Fleeing/Foot' 'Uncertain'
#  'Fleeing/Motorcycle' 'Fleeing/Bicycle']
#
# ['Washington_Post' 'Fatal_Encounters' 'undetermined']
# [nan 'Firearm/Handgun' 'Edged weapon/Knife' 'Firearm/Pellet gun'
#  'Firearm/Gun' 'Blunt object/Shovel' 'Firearm/Rifle' 'Blunt object/Hammer'
#  'Blunt object/Rock' 'Other/Broom' 'Firearm/Shotgun' 'Blunt object/Stick'
#  'Other/Bucket' 'Edged weapon/Machete' 'Edged weapon/Box cutter'
#  'Uncertain' 'Vehicle' 'Edged weapon/Sword' 'Blunt object/Metal pole'
#  'Edged weapon/Lawn mower blade' 'Firearm/Replica firearm'
#  'Blunt object/Flagpole' 'Edged weapon/Glass fragment'
#  'Edged weapon/Crossbow' 'Blunt object/Metal pipe' 'Other/Metal hand tool'
#  'Edged weapon/Screwdriver' 'Blunt object/Unspecified'
#  'Edged weapon/Unspecified' 'Blunt object/Cleaver' 'Other/Spoon'
#  'Blunt object/Vehicle jack' 'Blunt object/Chain'
#  "Blunt object/Contractor's level" 'Other/Sprayer hose nozzle'
#  'Blunt object/Railroad spike' 'Other/Stapler' 'Firearm/Long gun'
#  'Blunt object/Metal rod' 'Other/Bean-bag shotgun' 'Edged weapon/Cleaver'
#  'Blunt object/Baseball bat' 'Other/Lighter'
#  'Edged weapon/Claw-style garden tool' 'Edged weapon/ax'
#  'Blunt object/Pole' 'Edged weapon/Pickax' 'Edged weapon/Scissors'
#  'Blunt object/Flashlight' 'Other/Flip-flop' 'Edged weapon/Hatchet'
#  'Other/Cell phone' 'Blunt object/Baton' 'Edged weapon/Spear'
#  'Blunt object/Metal chair' 'Edged weapon/Butcher knife'
#  'Blunt object/Cordless drill' 'Other/Beer can' 'Stun gun' 'Other/Bow'
#  'Other/Metal key ring' 'Edged weapon/Chain saw' 'Blunt object/Pipe'
#  'Other/Vaping device' 'Blunt object/Brick' 'Other/Pepper spray'
#  'Edged weapon/Garden shears' 'Other/Hose spray nozzle' 'Other/Rake'
#  'Blunt object/Martial arts staff' 'Blunt object/Crowbar'
#  'Blunt object/Oar' 'Other/Sports trophy' 'Other/Bong (glass pipe)'
#  'Blunt object/Board' 'Other/Electric hair clippers' 'Other/Penlight'
#  'Edged weapon/Utility knife' 'Other/Pen' 'Other/Multitool'
#  'Blunt object/Police baton' 'Edged weapon/Pitchfork'
#  'Other/Lighter fluid' 'Blunt object/Metal bar' 'Other/Paint sprayer'
#  'Other/Replica sword' 'Other/Bear spray' 'Edged weapon/Ax'
#  'Blunt object/Pliers' 'Edged weapon/Ax handle' 'Blunt object/Handcuff'
#  'Edged weapon/Arrow' 'Blunt object/Pipe wrench' 'Other/Burglary tool'
#  'Other/Paint scraper' 'Other/Flashlight' 'Other/Plastic sword'
#  'Edged weapon/Broken bottle' 'Other/Battery pack'
#  'Other/Black sunglasses' 'Blunt object/Bar stool' 'Other/Wooden stake'
#  'Edged weapon/Surgical forceps' 'Edged weapon/Garden loppers'
#  'Blunt object/Chair' 'Blunt object/Rebar' 'Edged weapon/Glass bottle'
#  'Edged weapon/Bladed weapons' 'Edged weapon/Pruning shears'
#  'Other/Eyeglasses case' 'Other/Screwdriver' 'Other/Black facemask'
#  'Handgun' 'Firearm/gun' 'Edged weapon/Razor knife'
#  'Edged weapon/Glass shard' 'Edged weapon/Knives']
# [nan 'Firearm/Handgun' 'Edged weapon/Knife' 'Firearm/Pellet gun'
#  'Firearm/Gun' 'Blunt object/Shovel' 'Firearm/Rifle' 'Blunt object/Hammer'
#  'Blunt object/Rock' 'Other/Broom' 'Firearm/Shotgun' 'Blunt object/Stick'
#  'Other/Bucket' 'Edged weapon/Machete' 'Edged weapon/Box cutter'
#  'Uncertain' 'Vehicle' 'Edged weapon/Sword' 'Blunt object/Metal pole'
#  'Edged weapon/Lawn mower blade' 'Firearm/Replica firearm'
#  'Blunt object/Flagpole' 'Edged weapon/Glass fragment'
#  'Edged weapon/Crossbow' 'Blunt object/Metal pipe' 'Other/Metal hand tool'
#  'Edged weapon/Screwdriver' 'Blunt object/Unspecified'
#  'Edged weapon/Unspecified' 'Blunt object/Cleaver' 'Other/Spoon'
#  'Blunt object/Vehicle jack' 'Blunt object/Chain'
#  "Blunt object/Contractor's level" 'Other/Sprayer hose nozzle'
#  'Blunt object/Railroad spike' 'Other/Stapler' 'Firearm/Long gun'
#  'Blunt object/Metal rod' 'Other/Bean-bag shotgun' 'Edged weapon/Cleaver'
#  'Blunt object/Baseball bat' 'Other/Lighter'
#  'Edged weapon/Claw-style garden tool' 'Edged weapon/ax'
#  'Blunt object/Pole' 'Edged weapon/Pickax' 'Edged weapon/Scissors'
#  'Blunt object/Flashlight' 'Other/Flip-flop' 'Edged weapon/Hatchet'
#  'Other/Cell phone' 'Blunt object/Baton' 'Edged weapon/Spear'
#  'Blunt object/Metal chair' 'Edged weapon/Butcher knife'
#  'Blunt object/Cordless drill' 'Other/Beer can' 'Stun gun' 'Other/Bow'
#  'Other/Metal key ring' 'Edged weapon/Chain saw' 'Blunt object/Pipe'
#  'Other/Vaping device' 'Blunt object/Brick' 'Other/Pepper spray'
#  'Edged weapon/Garden shears' 'Other/Hose spray nozzle' 'Other/Rake'
#  'Blunt object/Martial arts staff' 'Blunt object/Crowbar'
#  'Blunt object/Oar' 'Other/Sports trophy' 'Other/Bong (glass pipe)'
#  'Blunt object/Board' 'Other/Electric hair clippers' 'Other/Penlight'
#  'Edged weapon/Utility knife' 'Other/Pen' 'Other/Multitool'
#  'Blunt object/Police baton' 'Edged weapon/Pitchfork'
#  'Other/Lighter fluid' 'Blunt object/Metal bar' 'Other/Paint sprayer'
#  'Other/Replica sword' 'Other/Bear spray' 'Edged weapon/Ax'
#  'Blunt object/Pliers' 'Edged weapon/Ax handle' 'Blunt object/Handcuff'
#  'Edged weapon/Arrow' 'Blunt object/Pipe wrench' 'Other/Burglary tool'
#  'Other/Paint scraper' 'Other/Flashlight' 'Other/Plastic sword'
#  'Edged weapon/Broken bottle' 'Other/Battery pack'
#  'Other/Black sunglasses' 'Blunt object/Bar stool' 'Other/Wooden stake'
#  'Edged weapon/Surgical forceps' 'Edged weapon/Garden loppers'
#  'Blunt object/Chair' 'Blunt object/Rebar' 'Edged weapon/Glass bottle'
#  'Edged weapon/Bladed weapons' 'Edged weapon/Pruning shears'
#  'Other/Eyeglasses case' 'Other/Screwdriver' 'Other/Black facemask'
#  'Handgun' 'Firearm/gun' 'Edged weapon/Razor knife'
#  'Edged weapon/Glass shard' 'Edged weapon/Knives']
# ['Washington_Post' 'undetermined' 'Fatal_Encounters']
# [nan 'Fatal_Encounters']
# [nan 'Brandished weapon' 'Reached to waist' 'Used weapon'
#  'Advanced toward officer(s)' 'Sudden threatening movement' 'Uncertain'
#  'None/Police alleged vehicular assault' 'Struggled'
#  'Intentional vehicular assault' 'Self-inflicted injury'
#  'None/Police alleged vehicular assault.' 'Advanced upon officer(s)'
#  'Used Weapon' 'Advanced on officer(s)']
# ['Uncertain' 'Brandished weapon' 'Reached to waist'
#  'Sudden threatening movement' 'Used weapon' nan
#  'Advanced toward officer(s)' 'None/Police alleged vehicular assault'
#  'Struggled' 'Intentional vehicular assault' 'Self-inflicted injury'
#  'None/Police alleged vehicular assault.' 'Advanced upon officer(s)'
#  'Duplicate of 13419?']
# ['Asian/Pacific Islander' 'European-American/White' 'Hispanic/Latino'
#  'Native American/Alaskan' 'African-American/Black' nan 'Race unspecified'
#  'Middle Eastern'
#  'African-American/Black African-American/Black Not imputed'
#  'European-American/European-American/White'
#  'Christopher Anthony Alexander']
# ['Asian/Pacific Islander' 'European-American/White' 'Hispanic/Latino'
#  'Native American/Alaskan' 'African-American/Black' nan 'Race unspecified'
#  'Middle Eastern'
#  'African-American/Black African-American/Black Not imputed'
#  'European-American/European-American/White'
#  'Christopher Anthony Alexander']
#
#
#
# ['pctwhite_x_x' 'pctwhite_y_x' 'pcthispanic_y_x' 'pcthispanic_x_x'
#  'pctapi_x_x' 'pctblack_x_x' 'pcthispanic_y_y' 'pctblack_y_x'
#  'pcthispanic_x_y' 'pctapi_y_x' 'pctwhite_x_y' 'pctaian_x_x' 'pctaian_y_x'
#  'pctapi_x_y' 'pctblack_x_y' 'pctwhite_y_y']

# %%
Index(
      dtype='object')

# %%
print(df.Retrieved_threat_type_v1.unique())
# Out:
# [nan 'Brandished weapon' 'Reached to waist' 'Used weapon'
#  'Advanced toward officer(s)' 'Sudden threatening movement' 'Uncertain'
#  'None/Police alleged vehicular assault' 'Struggled'
#  'Intentional vehicular assault' 'Self-inflicted injury'
#  'None/Police alleged vehicular assault.' 'Advanced upon officer(s)'
#  'Used Weapon' 'Advanced on officer(s)']
